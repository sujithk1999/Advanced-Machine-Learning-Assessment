# %%
pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Downloading tensorflow_gpu-2.9.1-cp38-cp38-win_amd64.whl (444.1 MB)
# Collecting keras-preprocessing>=1.1.1
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-14.0.6-py2.py3-none-win_amd64.whl (14.2 MB)
# Requirement already satisfied: numpy>=1.20 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.20.1)
# Collecting flatbuffers<2,>=1.12
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.15.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.47.0-cp38-cp38-win_amd64.whl (3.6 MB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp38-cp38-win_amd64.whl (895 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.26.0-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (3.7.4.3)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (52.0.0.post20210125)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (1.12.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-gpu) (20.9)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.36.2)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.9.1-py2.py3-none-any.whl (167 kB)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (2.25.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow-gpu) (1.0.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-4.12.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow-gpu) (3.4.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow-gpu) (2.10)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->tensorflow-gpu) (2.4.7)
# Building wheels for collected packages: termcolor
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=dc273d81991f00f02e3df097ce6a860524780649cdd8e0ebae822e82c80ca3fc
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, requests-oauthlib, importlib-metadata, google-auth, tensorboard-plugin-wit, tensorboard-data-server, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras-preprocessing, keras, google-pasta, gast, flatbuffers, astunparse, tensorflow-gpu
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
# Successfully installed absl-py-1.2.0 astunparse-1.6.3 cachetools-5.2.0 flatbuffers-1.12 gast-0.4.0 google-auth-2.9.1 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.47.0 importlib-metadata-4.12.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-14.0.6 markdown-3.4.1 oauthlib-3.2.0 opt-einsum-3.3.0 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-estimator-2.9.0 tensorflow-gpu-2.9.1 tensorflow-io-gcs-filesystem-0.26.0 termcolor-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Installing the game**

# %%
# !pip install gym_super_mario_bros==7.3.0 nes_py
# Out:
# Collecting gym_super_mario_bros==7.3.0
#   Downloading gym_super_mario_bros-7.3.0-py2.py3-none-any.whl (198 kB)
# Collecting nes_py
#   Downloading nes_py-8.2.1.tar.gz (77 kB)
# Collecting gym>=0.17.2
#   Downloading gym-0.25.1.tar.gz (732 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (1.20.1)
# Collecting pyglet<=1.5.21,>=1.4.0
#   Downloading pyglet-1.5.21-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (4.59.0)
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.7-py3-none-any.whl (2.7 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (1.6.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gym>=0.17.2->nes_py) (3.4.1)
# Building wheels for collected packages: nes-py, gym
#   Building wheel for nes-py (setup.py): started
#   Building wheel for nes-py (setup.py): finished with status 'done'
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp38-cp38-win_amd64.whl size=48249 sha256=4c6ee0df96dc8699f10555edf749c536489de7aea2dc182fd25d6349645ab596
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\17\e5\5c\8dfae61b44dbf56c458483aa09accef55a650e0527f6cbd872
#   Building wheel for gym (PEP 517): started
#   Building wheel for gym (PEP 517): finished with status 'done'
#   Created wheel for gym: filename=gym-0.25.1-py3-none-any.whl size=849029 sha256=d72e207341a11eb8d2a20ba88cc6e9b57c8a41574b7717a9f98d943232e2676b
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\cc\73\13\48bbc89268e1515e9e26f60c50ee870632c700c75cf7a53fbe
# Successfully built nes-py gym
# Installing collected packages: gym-notices, pyglet, gym, nes-py, gym-super-mario-bros
# Successfully installed gym-0.25.1 gym-notices-0.0.7 gym-super-mario-bros-7.3.0 nes-py-8.2.1 pyglet-1.5.21

# %% [markdown]
# **Importing the libraries**

# %%
# Importing the game
import gym_super_mario_bros
# Importing the Joypad wrapper
from nes_py.wrappers import JoypadSpace
# Importing the SIMPLIFIED controls
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

# %%
import os

from torchvision import transforms
import gym
from gym.spaces import Box
import gym_super_mario_bros
import numpy as np
import torch
from gym.wrappers import FrameStack
from nes_py.wrappers import JoypadSpace
from torch import nn
from torch.distributions import Categorical
import matplotlib.pyplot as plt
device = torch.device("cuda")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class SkipFrame(gym.Wrapper):
    def __init__(self, env, skip):
        super().__init__(env)
        self._skip = skip

    def step(self, action):
        total_reward = 0.0
        done = False
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            total_reward += reward
            if done:
                break
        return obs, total_reward, done, info
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Grayscaling for observation**

# %%
class GrayScaleObservation(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = Box(low=0, high=255, shape=self.observation_space.shape[:2], dtype=np.uint8)

    def observation(self, observation):
        transform = transforms.Grayscale()
        return transform(torch.tensor(np.transpose(observation, (2, 0, 1)).copy(), dtype=torch.float))

# %% [markdown]
# **Resizing the observation**

# %%
class ResizeObservation(gym.ObservationWrapper):
    def __init__(self, env, shape):
        super().__init__(env)
        self.shape = (shape, shape)
        obs_shape = self.shape + self.observation_space.shape[2:]
        self.observation_space = Box(low=0, high=255, shape=obs_shape, dtype=np.uint8)

    def observation(self, observation):
        transformations = transforms.Compose([transforms.Resize(self.shape), transforms.Normalize(0, 255)])
        return transformations(observation).squeeze(0)


env = gym_super_mario_bros.make('SuperMarioBros2-v0')
env = JoypadSpace(env, [["right"], ["right", "A"]])
env = FrameStack(ResizeObservation(GrayScaleObservation(SkipFrame(env, skip=4)), shape=84), num_stack=4)
env.seed(24)
env.action_space.seed(24)
torch.manual_seed(24)
torch.random.manual_seed(24)
np.random.seed(24)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gym\envs\registration.py:593: UserWarning: WARN: The environment SuperMarioBros2-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\gym\core.py:329: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(
# C:\ProgramData\Anaconda3\lib\site-packages\gym\wrappers\step_api_compatibility.py:39: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   deprecation(

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.actor = nn.Sequential(
            nn.Conv2d(in_channels=4, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, env.action_space.n)
        )
        self.critic = nn.Sequential(
            nn.Conv2d(in_channels=4, out_channels=32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, 1)
        )

    def forward(self, obs):
        return Categorical(logits=self.actor(obs)), self.critic(obs).reshape(-1)

# %%
class PPOSolver:
    def __init__(self):
        self.rewards = []
        self.gamma = 0.95
        self.lamda = 0.95
        self.worker_steps = 4096
        self.n_mini_batch = 4
        self.epochs = 30
        self.save_directory = r"C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE"
        self.batch_size = self.worker_steps
        self.mini_batch_size = self.batch_size // self.n_mini_batch
        self.obs = env.reset().__array__()
        self.policy = Model().to(device)
        self.mse_loss = nn.MSELoss()
        self.optimizer = torch.optim.Adam([
            {'params': self.policy.actor.parameters(), 'lr': 0.00025},
            {'params': self.policy.critic.parameters(), 'lr': 0.001}
        ], eps=1e-4)
        self.policy_old = Model().to(device)
        self.policy_old.load_state_dict(self.policy.state_dict())
        self.all_episode_rewards = []
        self.all_mean_rewards = []
        self.episode = 0

    def save_checkpoint(self):
        filename = os.path.join(self.save_directory, 'checkpoint_{}.pth'.format(self.episode))
        torch.save(self.policy_old.state_dict(), f=filename)
        print('Checkpoint saved to \'{}\''.format(filename))

    def load_checkpoint(self, filename):
        self.policy.load_state_dict(torch.load(os.path.join(self.save_directory, filename)))
        self.policy_old.load_state_dict(torch.load(os.path.join(self.save_directory, filename)))
        print('Resuming training from checkpoint \'{}\'.'.format(filename))

    def sample(self):
        rewards = np.zeros(self.worker_steps, dtype=np.float32)
        actions = np.zeros(self.worker_steps, dtype=np.int32)
        done = np.zeros(self.worker_steps, dtype=bool)
        obs = np.zeros((self.worker_steps, 4, 84, 84), dtype=np.float32)
        log_pis = np.zeros(self.worker_steps, dtype=np.float32)
        values = np.zeros(self.worker_steps, dtype=np.float32)
        for t in range(self.worker_steps):
            with torch.no_grad():
                obs[t] = self.obs
                pi, v = self.policy_old(torch.tensor(self.obs, dtype=torch.float32, device=device).unsqueeze(0))
                values[t] = v.cpu().numpy()
                a = pi.sample()
                actions[t] = a.cpu().numpy()
                log_pis[t] = pi.log_prob(a).cpu().numpy()
            self.obs, rewards[t], done[t], _ = env.step(actions[t])
            self.obs = self.obs.__array__()
            env.render()
            self.rewards.append(rewards[t])
            if done[t]:
                self.episode += 1
                self.all_episode_rewards.append(np.sum(self.rewards))
                self.rewards = []
                env.reset()
                if self.episode % 10 == 0:
                    print('Episode: {}, average reward: {}'.format(self.episode, np.mean(self.all_episode_rewards[-10:])))
                    self.all_mean_rewards.append(np.mean(self.all_episode_rewards[-10:]))
                    plt.plot(self.all_mean_rewards)
                    plt.savefig("{}/mean_reward_{}.png".format(self.save_directory, self.episode))
                    plt.clf()
                    self.save_checkpoint()
        returns, advantages = self.calculate_advantages(done, rewards, values)
        return {
            'obs': torch.tensor(obs.reshape(obs.shape[0], *obs.shape[1:]), dtype=torch.float32, device=device),
            'actions': torch.tensor(actions, device=device),
            'values': torch.tensor(values, device=device),
            'log_pis': torch.tensor(log_pis, device=device),
            'advantages': torch.tensor(advantages, device=device, dtype=torch.float32),
            'returns': torch.tensor(returns, device=device, dtype=torch.float32)
        }

    def calculate_advantages(self, done, rewards, values):
        _, last_value = self.policy_old(torch.tensor(self.obs, dtype=torch.float32, device=device).unsqueeze(0))
        last_value = last_value.cpu().data.numpy()
        values = np.append(values, last_value)
        returns = []
        gae = 0
        for i in reversed(range(len(rewards))):
            mask = 1.0 - done[i]
            delta = rewards[i] + self.gamma * values[i + 1] * mask - values[i]
            gae = delta + self.gamma * self.lamda * mask * gae
            returns.insert(0, gae + values[i])
        adv = np.array(returns) - values[:-1]
        return returns, (adv - np.mean(adv)) / (np.std(adv) + 1e-8)

    def train(self, samples, clip_range):
        indexes = torch.randperm(self.batch_size)
        for start in range(0, self.batch_size, self.mini_batch_size):
            end = start + self.mini_batch_size
            mini_batch_indexes = indexes[start: end]
            mini_batch = {}
            for k, v in samples.items():
                mini_batch[k] = v[mini_batch_indexes]
            for _ in range(self.epochs):
                loss = self.calculate_loss(clip_range=clip_range, samples=mini_batch)
                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()
            self.policy_old.load_state_dict(self.policy.state_dict())

    def calculate_loss(self, samples, clip_range):
        sampled_returns = samples['returns']
        sampled_advantages = samples['advantages']
        pi, value = self.policy(samples['obs'])
        ratio = torch.exp(pi.log_prob(samples['actions']) - samples['log_pis'])
        clipped_ratio = ratio.clamp(min=1.0 - clip_range, max=1.0 + clip_range)
        policy_reward = torch.min(ratio * sampled_advantages, clipped_ratio * sampled_advantages)
        entropy_bonus = pi.entropy()
        vf_loss = self.mse_loss(value, sampled_returns)
        loss = -policy_reward + 0.5 * vf_loss - 0.01 * entropy_bonus
        return loss.mean()

# %% [markdown]
# **Using PPO agent as solver**

# %%
solver = PPOSolver()
while True:
    solver.train(solver.sample(), 0.2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:227: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# C:\ProgramData\Anaconda3\lib\site-packages\gym\core.py:57: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   deprecation(
# C:\ProgramData\Anaconda3\lib\site-packages\gym\utils\passive_env_checker.py:280: UserWarning: WARN: No render modes was declared in the environment (env.metadata['render_modes'] is None or not defined), you may have trouble when calling `.render()`.
#   logger.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# Episode: 10, average reward: 1663.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_10.pth'
# Episode: 20, average reward: 1984.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_20.pth'
# Episode: 30, average reward: 1851.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_30.pth'
# Episode: 40, average reward: 1784.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_40.pth'
# Episode: 50, average reward: 2008.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_50.pth'
# Episode: 60, average reward: 1944.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_60.pth'
# Episode: 70, average reward: 2086.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_70.pth'
# Episode: 80, average reward: 2008.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_80.pth'
# Episode: 90, average reward: 1896.5999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_90.pth'
# Episode: 100, average reward: 1836.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_100.pth'
# Episode: 110, average reward: 2131.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_110.pth'
# Episode: 120, average reward: 2114.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_120.pth'
# Episode: 130, average reward: 2056.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_130.pth'
# Episode: 140, average reward: 1978.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_140.pth'
# Episode: 150, average reward: 1952.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_150.pth'
# Episode: 160, average reward: 1654.9000244140625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_160.pth'
# Episode: 170, average reward: 1992.0999755859375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_170.pth'
# Episode: 180, average reward: 2244.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_180.pth'
# Episode: 190, average reward: 2187.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_190.pth'
# Episode: 200, average reward: 2493.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_200.pth'
# Episode: 210, average reward: 2209.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_210.pth'
# Episode: 220, average reward: 2189.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_220.pth'
# Episode: 230, average reward: 2383.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_230.pth'
# Episode: 240, average reward: 2321.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_240.pth'
# Episode: 250, average reward: 2399.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_250.pth'
# Episode: 260, average reward: 2282.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_260.pth'
# Episode: 270, average reward: 2410.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_270.pth'
# Episode: 280, average reward: 2363.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_280.pth'
# Episode: 290, average reward: 2341.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_290.pth'
# Episode: 300, average reward: 2130.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_300.pth'
# Episode: 310, average reward: 2447.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_310.pth'
# Episode: 320, average reward: 2512.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_320.pth'
# Episode: 330, average reward: 2470.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_330.pth'
# Episode: 340, average reward: 2552.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_340.pth'
# Episode: 350, average reward: 2292.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_350.pth'
# Episode: 360, average reward: 2266.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_360.pth'
# Episode: 370, average reward: 2237.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_370.pth'
# Episode: 380, average reward: 2682.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_380.pth'
# Episode: 390, average reward: 2432.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_390.pth'
# Episode: 400, average reward: 2412.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_400.pth'
# Episode: 410, average reward: 2288.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_410.pth'
# Episode: 420, average reward: 2243.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_420.pth'
# Episode: 430, average reward: 2497.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_430.pth'
# Episode: 440, average reward: 2181.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_440.pth'
# Episode: 450, average reward: 1941.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_450.pth'
# Episode: 460, average reward: 2346.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_460.pth'
# Episode: 470, average reward: 2371.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_470.pth'
# Episode: 480, average reward: 2409.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_480.pth'
# Episode: 490, average reward: 2550.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_490.pth'
# Episode: 500, average reward: 2585.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_500.pth'
# Episode: 510, average reward: 2553.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_510.pth'
# Episode: 520, average reward: 2494.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_520.pth'
# Episode: 530, average reward: 2353.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_530.pth'
# Episode: 540, average reward: 2546.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_540.pth'
# Episode: 550, average reward: 2442.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_550.pth'
# Episode: 560, average reward: 2529.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_560.pth'
# Episode: 570, average reward: 2605.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_570.pth'
# Episode: 580, average reward: 2835.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_580.pth'
# Episode: 590, average reward: 2679.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_590.pth'
# Episode: 600, average reward: 2897.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_600.pth'
# Episode: 610, average reward: 3104.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_610.pth'
# Episode: 620, average reward: 2824.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_620.pth'
# Episode: 630, average reward: 2540.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_630.pth'
# Episode: 640, average reward: 2555.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_640.pth'
# Episode: 650, average reward: 2417.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_650.pth'
# Episode: 660, average reward: 2755.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_660.pth'
# Episode: 670, average reward: 2777.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_670.pth'
# Episode: 680, average reward: 2781.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_680.pth'
# Episode: 690, average reward: 2750.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_690.pth'
# Episode: 700, average reward: 2834.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_700.pth'
# Episode: 710, average reward: 2784.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_710.pth'
# Episode: 720, average reward: 2954.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_720.pth'
# Episode: 730, average reward: 2597.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_730.pth'
# Episode: 740, average reward: 2885.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_740.pth'
# Episode: 750, average reward: 2515.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_750.pth'
# Episode: 760, average reward: 2723.300048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_760.pth'
# Episode: 770, average reward: 2923.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_770.pth'
# Episode: 780, average reward: 3054.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_780.pth'
# Episode: 790, average reward: 3024.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_790.pth'
# Episode: 800, average reward: 3109.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_800.pth'
# Episode: 810, average reward: 2792.60009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_810.pth'
# Episode: 820, average reward: 2755.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_820.pth'
# Episode: 830, average reward: 3163.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_830.pth'
# Episode: 840, average reward: 3108.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_840.pth'
# Episode: 850, average reward: 2897.89990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_850.pth'
# Episode: 860, average reward: 2792.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_860.pth'
# Episode: 870, average reward: 3030.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_870.pth'
# Episode: 880, average reward: 3078.5
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_880.pth'
# Episode: 890, average reward: 3326.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_890.pth'
# Episode: 900, average reward: 2991.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_900.pth'
# Episode: 910, average reward: 3173.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_910.pth'
# Episode: 920, average reward: 2996.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_920.pth'
# Episode: 930, average reward: 3257.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_930.pth'
# Episode: 940, average reward: 3330.0
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_940.pth'
# Episode: 950, average reward: 3186.699951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_950.pth'
# Episode: 960, average reward: 3262.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_960.pth'
# Episode: 970, average reward: 3353.10009765625
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_970.pth'
# Episode: 980, average reward: 3171.39990234375
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_980.pth'
# Episode: 990, average reward: 3387.800048828125
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_990.pth'
# Episode: 1000, average reward: 3066.199951171875
# Checkpoint saved to 'C:\Users\Computing\Desktop\PPO SEED =24 WITHOUTBASELINE\checkpoint_1000.pth'
